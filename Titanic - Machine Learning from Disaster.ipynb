# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\mayur\Downloads\train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#checking null values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
plt.figure(figsize=(8, 4))
plt.title('Sex Percentage')
plt.ylabel('Percent')
percent=df.Sex.value_counts()*100/len(df)

# Plot the bars
bars = percent.plot(kind='bar')

# Annotate each bar
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
# Assuming df is your DataFrame
plt.figure(figsize=(8, 4))
plt.title('Percentage of Survival')
plt.ylabel('Percentage')

# This is your series of percentages
percentages = (df.Survived.value_counts() * 100 / len(df))

# Plot the bars
bars = percentages.plot(kind='bar')

# Annotate each bar
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
plt.figure(figsize=(10, 6))
ax = pd.crosstab(df['Survived'], df['Sex'], normalize='columns').plot(kind='bar')

plt.title('Percentage of Survival by Sex')
plt.ylabel('Percent')

# Adding annotations with percentages
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2.,
            height + 0.02,  # small offset to place text above the bar
            '{:1.2f}%'.format(height*100),
            ha="center")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
plt.figure(figsize=(10, 6))
ax = pd.crosstab(df['Sex'], df['Survived'], normalize='columns').plot(kind='bar')

plt.title('Percentage of Survival by Sex')
plt.ylabel('Percent')

# Adding annotations with percentages
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2.,
            height + 0.02,  # small offset to place text above the bar
            '{:1.2f}%'.format(height*100),
            ha="center")

plt.show()

# %%
# Assuming df is your DataFrame
plt.figure(figsize=(8, 4))
plt.title('Percentage of Pclass')
plt.ylabel('Percent')

# This is your series of percentages
percentages = (df.Pclass.value_counts() * 100 / len(df))

# Plot the bars
bars = percentages.plot(kind='bar')

# Annotate each bar
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.title('Sex Percentage')
plt.ylabel('Percent')
bars=(df.Sex.value_counts()*100/len(df)).plot(kind='bar')
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.title('Age Distribution')
df.Age.plot(kind='hist' )
# Out:
# <Axes: title={'center': 'Age Distribution'}, ylabel='Frequency'>

# %%
sns.boxplot(x='Age', data=df)
plt.title('Age Distribution')
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.title('Ticket Fare Distribution')
bar=df.Fare.plot(kind='hist', )

# %%
plt.figure(figsize=(10, 5))
plt.title('Percentage of number of siblings / spouses aboard the Titanic')
plt.ylabel('Percent')
plt.xlabel('number of siblings / spouses aboard the Titanic')
bars=(df.SibSp.value_counts()*100/len(df)).plot(kind='bar',ax=plt.gca())

for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.title('Percentage of number of parents / children aboard the Titanic')
plt.ylabel('Percent')
plt.xlabel('number of parents / children aboard the Titanic')
bars=(df.Parch.value_counts()*100/len(df)).plot(kind='bar',ax=plt.gca())

for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.title('Percentage of Port of Embarkation')
plt.ylabel('Percent')
bars=(df.Embarked.value_counts()*100/len(df)).plot(kind='bar',ax=plt.gca())

for bars in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.title('Count of Survival with respect to Pclass')
plt.ylabel('Count')
bars=pd.crosstab(df['Survived'],df['Pclass']).plot(kind='bar',ax=plt.gca())

for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.title('Percentage of Survival with respect to Pclass')
plt.ylabel('Percentage')
bars=(pd.crosstab(df['Survived'],df['Pclass'],normalize='columns')*100).plot(kind='bar',ax=plt.gca())

for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.title('Count of Survival with respect to Sex')
plt.ylabel('Count')
bars=pd.crosstab(df['Survived'],df['Sex']).plot(kind='bar',ax=plt.gca())

for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.title('Percentage of Survival with respect to Sex')
plt.ylabel('Percent')
bars=(pd.crosstab(df['Survived'],df['Sex'],normalize='columns')*100).plot(kind='bar',ax=plt.gca())

for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.title('Count of Survuval with respect to Pclass')
plt.ylabel('')
bars=(pd.crosstab(df['Pclass'],df['Sex'])).plot(kind='bar',ax=plt.gca())

for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.title('Count of Survival with respect to Pclass')
plt.ylabel('')
bars=pd.crosstab(df['Pclass'],df['Sex'],values=df.Survived,aggfunc='count',normalize='index').plot(kind='bar',ax=plt.gca())

# %%
sns.boxplot(x='Sex', y='Fare', data=df)
plt.title('Fare by Gender')
plt.show()

# %%
sns.boxplot(x='Pclass', y='Fare', data=df)
plt.title('Fare Distribution by Pclass')
plt.show()

# %%
sns.boxplot(x='SibSp', y='Fare', data=df)
plt.title('Fare Distribution by Pclass')
plt.show()

# %%
sns.boxplot(x='Sex', y='Age', data=df)
plt.title('Age Distribution by Sex')
plt.show()

# %%
sns.boxplot(x='Pclass', y='Age', data=df)
plt.title('Age Distribution by Pclass')
plt.show()

# %%
sns.boxplot(x='SibSp', y='Fare', data=df)
plt.title('Age Distribution by number of siblings / spouses aboard the Titanic')
plt.show()

# %%
sns.boxplot(x='Parch', y='Age', data=df)
plt.title('Ditribution of Age with respect to number of parents / children aboard the Titanic')

plt.show()

# %%
sns.boxplot(x='Parch', y='Fare', data=df)
plt.title('Ditribution of Fare with respect to number of parents / children aboard the Titanic')
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.title('Average Fare with respect to Number of parents / children aboard the Titanic')
bars=df.groupby('Parch')['Fare'].mean().plot(kind='bar',ax=plt.gca())


for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Average Age with respect to Number of parents / children aboard the Titanic')
bars=df.groupby('Parch')['Age'].mean().plot(kind='bar',ax=plt.gca())
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(8,4))
plt.title('Average Fare with respect to Pclass')
bars=df.groupby('Pclass')['Fare'].mean().plot(kind='bar',ax=plt.gca())

for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(8,4))
plt.title('Average Fare with Respect to Sex')
bars=df.groupby('Sex')['Fare'].mean().plot(kind='bar',ax=plt.gca())

for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(8,4))
plt.title('Average Age with Respect to Sex')
bars=df.groupby('Pclass')['Age'].mean().plot(kind='bar',ax=plt.gca())

for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(8,4))
plt.title('Average Age with Respect to Sex')
bars=df.groupby('Sex')['Age'].mean().plot(kind='bar',ax=plt.gca())

for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # END
